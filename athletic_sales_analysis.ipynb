# %%
# Import Libraries and Dependencies
import pandas as pd

# %% [markdown]
# ### 1. Combine and Clean the Data
# #### Import CSVs

# %%
# Read the CSV files into DataFrames.
as_2020_df = pd.read_csv("../Challenge 5/Resources/athletic_sales_2020.csv")
as_2021_df = pd.read_csv("../Challenge 5/Resources/athletic_sales_2021.csv")

# %%
# Display the 2020 sales DataFrame
as_2020_df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732       1/1/20  Northeast      New York
# 1     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3     Foot Locker      1185732       1/1/20  Northeast      New York
# 4     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 1292    West Gear      1128299     12/30/20       West    California
# 1293    West Gear      1128299     12/30/20       West    California
# 1294       Kohl's      1189833     12/30/20    Midwest     Minnesota
# 1295       Kohl's      1189833     12/30/20    Midwest     Minnesota
# 1296    West Gear      1128299     12/30/20       West    California
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %%
# Display the 2021 sales DataFrame
as_2021_df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0       West Gear      1128299       1/1/21       West    California
# 1       West Gear      1128299       1/1/21       West    California
# 2          Kohl's      1189833       1/1/21    Midwest       Montana
# 3          Kohl's      1189833       1/1/21    Midwest       Montana
# 4       West Gear      1128299       1/1/21       West    California
# ...           ...          ...          ...        ...           ...
# 8341  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8342  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8343       Amazon      1185732     12/31/21  Northeast         Maine
# 8344       Amazon      1185732     12/31/21  Northeast         Maine
# 8345  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %% [markdown]
# #### Check the data types of each DataFrame

# %%
# Check the 2020 sales data types.
as_2020_df.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %%
# Check the 2021 sales data types.
as_2021_df.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %% [markdown]
# #### Combine the sales data by rows.

# %%
# Combine the 2020 and 2021 sales DataFrames on the rows and reset the index.
combine_as_data = pd.concat([as_2020_df, as_2021_df], axis="rows")
combine_as_data1 = combine_as_data.reset_index(drop=True)
combine_as_data1
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732       1/1/20  Northeast      New York
# 1     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3     Foot Locker      1185732       1/1/20  Northeast      New York
# 4     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 9638  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 9639  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 9640       Amazon      1185732     12/31/21  Northeast         Maine
# 9641       Amazon      1185732     12/31/21  Northeast         Maine
# 9642  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
#               city                product  price_per_unit  units_sold  \
# ...

# %%
# Check if any values are null.
combine_as_data1.isnull()
# Out:
#       retailer  retailer_id  invoice_date  region  state   city  product  \
# 0        False        False         False   False  False  False    False
# 1        False        False         False   False  False  False    False
# 2        False        False         False   False  False  False    False
# 3        False        False         False   False  False  False    False
# 4        False        False         False   False  False  False    False
# ...        ...          ...           ...     ...    ...    ...      ...
# 9638     False        False         False   False  False  False    False
# 9639     False        False         False   False  False  False    False
# 9640     False        False         False   False  False  False    False
# 9641     False        False         False   False  False  False    False
# 9642     False        False         False   False  False  False    False
#
#       price_per_unit  units_sold  total_sales  operating_profit  sales_method
# ...

# %%
# Check the data type of each column
combine_as_data1.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %%
# Convert the "invoice_date" to a datetime datatype
#combine_as_datetime = combine_as_data1.astype({"invoice_date" : datetime64[ns]})
combine_as_data1['invoice_date'] = pd.to_datetime(combine_as_data1['invoice_date'])
# Out:
# retailer                    object
# retailer_id                  int64
# invoice_date        datetime64[ns]
# region                      object
# state                       object
# city                        object
# product                     object
# price_per_unit               int64
# units_sold                   int64
# total_sales                  int64
# operating_profit           float64
# sales_method                object
# dtype: object

# %%
# Confirm that the "invoice_date" data type has been changed.
combine_as_data1.dtypes
# Out:
# retailer                    object
# retailer_id                  int64
# invoice_date        datetime64[ns]
# region                      object
# state                       object
# city                        object
# product                     object
# price_per_unit               int64
# units_sold                   int64
# total_sales                  int64
# operating_profit           float64
# sales_method                object
# dtype: object

# %% [markdown]
# ### 2. Determine which Region Sold the Most Products

# %% [markdown]
# #### Using `groupby`

# %%
# Show the number products sold for region, state, and city.
total_products_as = combine_as_data1.groupby(["region", "state", "city"])[["units_sold"]].agg('sum')
total_products_as
# Rename the sum to "Total_Products_Sold".
total_products_as_rename = total_products_as.rename(columns={"units_sold": "Total_Products_Sold"})
total_products_as_rename 
# Show the top 5 results.
total_products_as_rename.sort_values(by=["Total_Products_Sold","region", "state", "city"], ascending=False).head(5)
# Out:
#                                     Total_Products_Sold
# region    state        city
# Midwest   Nebraska     Omaha                      19154
#           Minnesota    Minneapolis                20415
# Northeast Maryland     Baltimore                  20818
#           Maine        Portland                   22410
# Midwest   North Dakota Fargo                      22781

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the number products sold for region, state, and city.
total_products_as_pv = pd.pivot_table(combine_as_data1,
                                        index=["region", "state", "city"],
                                        values="units_sold",
                                        aggfunc=sum)
total_products_as_pv
# Rename the "units_sold" column to "Total_Products_Sold"
total_products_as_pv = total_products_as_pv.rename(columns={"units_sold": "Total_Products_Sold"})
total_products_as_pv
# Show the top 5 results.
total_products_as_pv.sort_values(by=["Total_Products_Sold","region", "state", "city"], ascending=False).head(5)
# Out:
# C:\Users\moldr\AppData\Local\Temp\ipykernel_2532\2590412632.py:2: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   total_products_as_pv = pd.pivot_table(combine_as_data1,
#                                     Total_Products_Sold
# region    state        city
# Midwest   Nebraska     Omaha                      19154
#           Minnesota    Minneapolis                20415
# Northeast Maryland     Baltimore                  20818
#           Maine        Portland                   22410
# Midwest   North Dakota Fargo                      22781

# %% [markdown]
# ### 3. Determine which Region had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the number products sold for region, state, and city.
total_products_as = combine_as_data1.groupby(["region", "state", "city"])[["total_sales"]].agg('sum')
total_products_as
# Optional: Rename the "total_sales" column to "Total Sales"
total_products_as_rename = total_products_as.rename(columns={"total_sales": "Total Sales"})
total_products_as_rename 
# Show the top 5 results.
total_products_as_rename.sort_values(by=["Total Sales","region", "state", "city"], ascending=False).head(5)
# Out:
#                                   Total Sales
# region  state        city
# Midwest Nebraska     Omaha            5929038
#         Minnesota    Minneapolis      7227506
#         Iowa         Des Moines       7424011
#         Wisconsin    Milwaukee        7727469
#         North Dakota Fargo            7735580

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each region, state, and city.
total_products_as_pv = pd.pivot_table(combine_as_data1,
                                        index=["region", "state", "city"],
                                        values="total_sales",
                                        aggfunc=sum)
total_products_as_pv

# Optional: Rename the "total_sales" column to "Total Sales"
total_products_as_pv = total_products_as_pv.rename(columns={"total_sales": "Total Sales"})
total_products_as_pv

# Show the top 5 results.
total_products_as_pv.sort_values(by=["Total Sales","region", "state", "city"], ascending=False).head(5)
# Out:
# C:\Users\moldr\AppData\Local\Temp\ipykernel_2532\1512499937.py:2: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   total_products_as_pv = pd.pivot_table(combine_as_data1,
#                                   Total Sales
# region  state        city
# Midwest Nebraska     Omaha            5929038
#         Minnesota    Minneapolis      7227506
#         Iowa         Des Moines       7424011
#         Wisconsin    Milwaukee        7727469
#         North Dakota Fargo            7735580

# %% [markdown]
# ### 4. Determine which Retailer had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
total_products_as = combine_as_data1.groupby(["retailer", "region", "state", "city"])[["total_sales"]].agg('sum')
total_products_as
# Rename the "total_sales" column to "Total Sales"
total_products_as_rename = total_products_as.rename(columns={"total_sales": "Total Sales"})
total_products_as_rename 

# Show the top 5 results.
total_products_as_rename.sort_values(by=["Total Sales", "retailer", "region", "state", "city"], ascending=False).head(5)
# Out:
#                                               Total Sales
# retailer    region    state      city
# Foot Locker South     Tennessee  Knoxville         321225
# Amazon      South     Alabama    Birmingham        409091
# Foot Locker South     Texas      Dallas            420816
#             West      California Los Angeles       507753
# West Gear   Northeast Maine      Portland          584583

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
total_products_as_pv = pd.pivot_table(combine_as_data1,
                                        index=["retailer", "region", "state", "city"],
                                        values="total_sales",
                                        aggfunc=sum)
total_products_as_pv
# Optional: Rename the "total_sales" column to "Total Sales"
total_products_as_pv = total_products_as_pv.rename(columns={"total_sales": "Total Sales"})
total_products_as_pv

# Show the top 5 results.
total_products_as_pv.sort_values(by=["Total Sales","retailer", "region", "state", "city"], ascending=False).head(5)
# Out:
# C:\Users\moldr\AppData\Local\Temp\ipykernel_2532\3745682248.py:2: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   total_products_as_pv = pd.pivot_table(combine_as_data1,
#                                               Total Sales
# retailer    region    state      city
# Foot Locker South     Tennessee  Knoxville         321225
# Amazon      South     Alabama    Birmingham        409091
# Foot Locker South     Texas      Dallas            420816
#             West      California Los Angeles       507753
# West Gear   Northeast Maine      Portland          584583

# %% [markdown]
# ### 5. Determine which Retailer Sold the Most Women's Athletic Footwear

# %%
# Filter the sales data to get the women's athletic footwear sales data.
total_products_wf_as = pd.DataFrame(combine_as_data1.loc[combine_as_data1["product"]== "Women's Athletic Footwear",:])
total_products_wf_as
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 21    Foot Locker      1185732       1/4/20  Northeast      New York
# 22    Foot Locker      1185732       1/4/20  Northeast      New York
# 23    Foot Locker      1185732       1/4/20  Northeast      New York
# 26      West Gear      1128299       1/5/20  Northeast  Pennsylvania
# 27      West Gear      1128299       1/5/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 9633  Foot Locker      1185732     12/30/21  Northeast  Pennsylvania
# 9634  Foot Locker      1185732     12/30/21  Northeast  Pennsylvania
# 9635       Amazon      1185732     12/30/21  Northeast         Maine
# 9636       Amazon      1185732     12/30/21  Northeast         Maine
# 9637  Foot Locker      1185732     12/30/21  Northeast  Pennsylvania
#
#               city                    product  price_per_unit  units_sold  \
# ...

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
total_products_ws_as = total_products_wf_as.groupby(["retailer", "region", "state", "city"])[["units_sold"]].agg('sum')
total_products_ws_as

# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"
total_products_as_ws_rename = total_products_ws_as.rename(columns={"units_sold": "Units Sold"})
total_products_as_ws_rename

# Show the top 5 results.
total_products_as_ws_rename.sort_values(by=["Units Sold","retailer", "region", "state", "city"], ascending=False).head(5)
# Out:
#                                                       Units Sold
# retailer      region    state          city
# West Gear     West      California     San Francisco       12107
# Foot Locker   Northeast New York       New York            10996
# Kohl's        West      California     Los Angeles         10826
# Foot Locker   Southeast South Carolina Charleston           8814
# Sports Direct South     Texas          Dallas               8790

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
total_products_wf_as_pv = pd.pivot_table(total_products_wf_as,
                                        index=["region", "state", "city"],
                                        values="units_sold",
                                        aggfunc=sum)
total_products_wf_as_pv

# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"
total_products_as_pv_rename = total_products_wf_as_pv.rename(columns={"units_sold": "Units Sold"})
total_products_as_pv_rename

# Show the top 5 results..sort_values(by=["Units Sold","region", "state", "city"], ascending=False).head(5)
total_products_as_pv_rename.sort_values(by=["Units Sold", "region", "state", "city"], ascending=False).head(5)
# Out:
# C:\Users\moldr\AppData\Local\Temp\ipykernel_2532\83292299.py:2: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   total_products_wf_as_pv = pd.pivot_table(total_products_wf_as,
#                                         Units Sold
# region    state          city
# Northeast New York       New York            16392
# West      California     San Francisco       12999
# South     Texas          Houston             12727
# West      California     Los Angeles         11026
# Southeast South Carolina Charleston          10531

# %% [markdown]
# ### 6. Determine the Day with the Most Women's Athletic Footwear Sales

# %%
# Create a pivot table with the 'invoice_date' column is the index, and the "total_sales" as the values.
invoice_products_wf_as_pv = pd.pivot_table(total_products_wf_as,
                                        index=["invoice_date"],
                                        values=[ "total_sales"])
invoice_products_wf_as_pv

# Optional: Rename the "total_sales" column to "Total Sales"
invoice_products_wf_as_pv_rename = invoice_products_wf_as_pv.rename(columns={"total_sales": "Total Sales"})
invoice_products_wf_as_pv_rename

# Show the table.
invoice_products_wf_as_pv_rename
# Out:
#                 Total Sales
# invoice_date
# 1/10/21        28714.454545
# 1/11/20        43185.333333
# 1/11/21        33292.000000
# 1/12/21        57956.142857
# 1/13/21        51352.800000
# ...                     ...
# 9/6/21         20683.800000
# 9/7/21         48204.800000
# 9/8/20        145221.200000
# 9/8/21        121139.000000
# 9/9/21         77726.000000
#
# [355 rows x 1 columns]

# %%
# Resample the pivot table into daily bins, and get the total sales for each day.
sales_data_df = invoice_products_wf_as_pv_rename.set_index('invoice_date', inplace=False)

sales_data_df
#rs_wf = invoice_products_wf_as_pv_rename.set_index("invoice_date")
#rs_wf
# Sort the resampled pivot table in descending order on "Total Sales".
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2532\2517549824.py in ?()
#       1 # Resample the pivot table into daily bins, and get the total sales for each day.
# ----> 2 sales_data_df = invoice_products_wf_as_pv_rename.set_index('invoice_date', inplace=False)
#       3
#       4 sales_data_df
#       5 #rs_wf = invoice_products_wf_as_pv_rename.set_index("invoice_date")
#
# c:\Users\moldr\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5866                     if not found:
#    5867                         missing.append(col)
#    5868
#    5869         if missing:
# -> 5870             raise KeyError(f"None of {missing} are in the columns")
#    5871
#    5872         if inplace:
#    5873             frame = self
#
# KeyError: "None of ['invoice_date'] are in the columns"

# %% [markdown]
# ### 7.  Determine the Week with the Most Women's Athletic Footwear Sales

# %%
# Resample the pivot table into weekly bins, and get the total sales for each week.


# Sort the resampled pivot table in descending order on "Total Sales".
# Out:
#               Total Sales
# invoice_date
# 2021-12-19        3098970
# 2021-12-12        2922161
# 2021-07-11        2835078
# 2021-07-18        2801449
# 2021-11-14        2531721
# 2021-08-22        2491259
# 2021-08-15        2463941
# 2021-11-21        2449537
# 2021-05-16        2422132
# 2021-06-13        2358602
